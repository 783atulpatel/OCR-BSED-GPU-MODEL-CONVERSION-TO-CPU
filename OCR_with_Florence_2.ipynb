# %%
import cv2
import requests
from PIL import Image, ImageDraw
from transformers import AutoModelForCausalLM, AutoProcessor
import numpy as np
import random
from skimage.metrics import structural_similarity as ssim
from time import time

# Initialize Florence-2 Model
# !mkdir -p my_models/Florence_2

model = AutoModelForCausalLM.from_pretrained("microsoft/Florence-2-large-ft",
                                             cache_dir="/content/my_models/Florence_2",
                                             device_map="cuda",
                                             trust_remote_code=True)

processor = AutoProcessor.from_pretrained("microsoft/Florence-2-large-ft",
                                             cache_dir="/content/my_models/Florence_2",
                                             device_map="cuda",
                                             trust_remote_code=True)

def extract_frames(video_path, target_fps=20):
    cap = cv2.VideoCapture(video_path)
    frames = []
    frame_rate = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(frame_rate / target_fps)
    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if frame_count % frame_interval == 0:
            frames.append(frame)
        frame_count += 1
    cap.release()
    return frames

def compute_similarity(frame1, frame2):
    """Compute similarity between two frames using SSIM."""
    gray1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY)
    return ssim(gray1, gray2)

def process_frame_with_florence(frame):
    image = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    prompt = '<OCR_WITH_REGION>'
    inputs = processor(text=prompt, images=image, return_tensors="pt").to("cuda:0")
    start_time = time()
    generated_ids = model.generate(
        input_ids=inputs["input_ids"],
        pixel_values=inputs["pixel_values"],
        max_new_tokens=4096,
        num_beams=3
    )
    processing_time = time() - start_time
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]
    parsed_answer = processor.post_process_generation(generated_text, task=prompt, image_size=(image.width, image.height))
    ocr_text = parsed_answer['<OCR_WITH_REGION>']
    return ocr_text, image, processing_time

def draw_ocr_bboxes(image, prediction):
    scale = 1
    colormap = ['blue', 'orange', 'green', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'red',
                'lime', 'indigo', 'violet', 'aqua', 'magenta', 'coral', 'gold', 'tan', 'skyblue']
    draw = ImageDraw.Draw(image)
    bboxes, labels = prediction['quad_boxes'], prediction['labels']
    for box, label in zip(bboxes, labels):
        color = random.choice(colormap)
        new_box = (np.array(box) * scale).tolist()
        draw.polygon(new_box, width=3, outline=color)
    return image

def main(video_path):
    frames = extract_frames(video_path)
    last_frame = None
    frame_times = []
    start_time = time()

    for i, frame in enumerate(frames):
        if last_frame is not None:
            similarity = compute_similarity(last_frame, frame)
            if similarity > 0.95:  # Adjust threshold as needed
                print(f"Frame {i + 1} is similar to the last processed frame. Skipping...")
                continue

        ocr_text_dict, image, processing_time = process_frame_with_florence(frame)
        frame_times.append(processing_time)

        print(f"Frame {i + 1} OCR Text: {ocr_text_dict}")  # Print the parsed text
        print(f"Frame {i + 1} Processing Time: {processing_time:.2f} seconds")

        output_image = draw_ocr_bboxes(image, ocr_text_dict)
        output_image.show()  # Display the image
        last_frame = frame  # Update the last processed frame

    # Compute overall metrics
    average_processing_time = sum(frame_times) / len(frame_times) if frame_times else 0
    fps = len(frames) / (time() - start_time) if len(frames) > 0 else 0

    print(f"Overall Average Processing Time: {average_processing_time:.2f} seconds")
    print(f"Overall FPS: {fps:.2f}")

# Example usage
video_path = 'test1.mp4'
main(video_path)
# Out:
# Frame 1 OCR Text: {'quad_boxes': [[85.97900390625, 108.18000793457031, 158.6230010986328, 108.18000793457031, 158.6230010986328, 129.77999877929688, 85.97900390625, 129.77999877929688], [7.23900032043457, 139.5, 247.26901245117188, 139.13999938964844, 247.26901245117188, 154.260009765625, 7.23900032043457, 155.3400115966797], [3.1750001907348633, 161.82000732421875, 246.5070037841797, 161.82000732421875, 246.5070037841797, 176.22000122070312, 3.1750001907348633, 176.22000122070312], [3.1750001907348633, 182.3400115966797, 245.74501037597656, 182.3400115966797, 245.74501037597656, 197.10000610351562, 3.1750001907348633, 197.10000610351562], [3.1750001907348633, 203.5800018310547, 229.74301147460938, 203.5800018310547, 229.74301147460938, 220.1400146484375, 3.1750001907348633, 220.1400146484375], [3.1750001907348633, 225.1800079345703, 231.2670135498047, 225.1800079345703, 231.2670135498047, 241.3800048828125, 3.1750001907348633, 241.74000549316406], [3.1750001907348633, 247.1400146484375, 235.07701110839844, 247.50001525878906, 235.07701110839844, 262.9800109863281, 3.1750001907348633, 262.260009765625], [3.1750001907348633, 268.7400207519531, 241.427001953125, 268.7400207519531, 241.427001953125, 284.94000244140625, 3.1750001907348633, 285.3000183105469], [3.1750001907348633, 289.9800109863281, 250.82501220703125, 289.9800109863281, 250.82501220703125, 305.82000732421875, 3.1750001907348633, 305.82000732421875], [3.1750001907348633, 311.58001708984375, 235.07701110839844, 311.58001708984375, 235.07701110839844, 328.1400146484375, 3.1750001907348633, 328.1400146484375], [122.3010025024414, 331.3800048828125, 130.93701171875, 331.3800048828125, 131.19100952148438, 343.6200256347656, 122.3010025024414, 343.6200256347656], [16.38300132751465, 345.4200134277344, 245.74501037597656, 345.4200134277344, 245.74501037597656, 356.58001708984375, 16.38300132751465, 356.58001708984375]], 'labels': ['</s>Water', 'Every day we waste a lot of water and', 'food. Water, in particular, is a renewable', "resource but it's also limited. We can", 'find, purify and package it, but we', "can't produce it! No life is possible", 'without water. Saving water means', 'protecting life on earth and gives us', 'the chance to provide food and water', "for people who don't have enough.", '1', 'Copyright 2020 by : FB group ( worksheets PDF )']}
# Frame 1 Processing Time: 2.99 seconds
# Frame 2 is similar to the last processed frame. Skipping...
# Frame 3 is similar to the last processed frame. Skipping...
# Frame 4 is similar to the last processed frame. Skipping...
# Frame 5 is similar to the last processed frame. Skipping...
# Frame 6 is similar to the last processed frame. Skipping...
# Frame 7 is similar to the last processed frame. Skipping...
# Frame 8 is similar to the last processed frame. Skipping...
# Frame 9 is similar to the last processed frame. Skipping...
# Frame 10 is similar to the last processed frame. Skipping...
# Frame 11 is similar to the last processed frame. Skipping...
# Frame 12 is similar to the last processed frame. Skipping...
# Frame 13 is similar to the last processed frame. Skipping...
# Frame 14 is similar to the last processed frame. Skipping...
# Frame 15 is similar to the last processed frame. Skipping...
# Frame 16 is similar to the last processed frame. Skipping...
# Frame 17 is similar to the last processed frame. Skipping...
# Frame 18 is similar to the last processed frame. Skipping...
# Frame 19 is similar to the last processed frame. Skipping...
# Frame 20 is similar to the last processed frame. Skipping...
# Frame 21 is similar to the last processed frame. Skipping...
# Frame 22 is similar to the last processed frame. Skipping...
# Frame 23 is similar to the last processed frame. Skipping...
# Frame 24 is similar to the last processed frame. Skipping...
# Frame 25 is similar to the last processed frame. Skipping...
# Frame 26 is similar to the last processed frame. Skipping...
# Frame 27 is similar to the last processed frame. Skipping...
# Frame 28 is similar to the last processed frame. Skipping...
# Frame 29 is similar to the last processed frame. Skipping...
# Frame 30 is similar to the last processed frame. Skipping...
# Frame 31 is similar to the last processed frame. Skipping...
# Frame 32 is similar to the last processed frame. Skipping...
# Frame 33 is similar to the last processed frame. Skipping...
# Frame 34 is similar to the last processed frame. Skipping...
# Frame 35 is similar to the last processed frame. Skipping...
# Frame 36 is similar to the last processed frame. Skipping...
# Frame 37 is similar to the last processed frame. Skipping...
# Frame 38 is similar to the last processed frame. Skipping...
# Frame 39 is similar to the last processed frame. Skipping...
# Frame 40 is similar to the last processed frame. Skipping...
# Frame 41 is similar to the last processed frame. Skipping...
# Frame 42 is similar to the last processed frame. Skipping...
# Frame 43 is similar to the last processed frame. Skipping...
# Frame 44 is similar to the last processed frame. Skipping...
# Frame 45 is similar to the last processed frame. Skipping...
# Frame 46 is similar to the last processed frame. Skipping...
# Frame 47 is similar to the last processed frame. Skipping...
# Frame 48 is similar to the last processed frame. Skipping...
# Frame 49 is similar to the last processed frame. Skipping...
# Frame 50 is similar to the last processed frame. Skipping...
# Frame 51 is similar to the last processed frame. Skipping...
# Frame 52 is similar to the last processed frame. Skipping...
# Frame 53 is similar to the last processed frame. Skipping...
# Frame 54 is similar to the last processed frame. Skipping...
# Frame 55 is similar to the last processed frame. Skipping...
# Frame 56 is similar to the last processed frame. Skipping...
# Frame 57 is similar to the last processed frame. Skipping...
# Frame 58 is similar to the last processed frame. Skipping...
# Frame 59 is similar to the last processed frame. Skipping...
# Frame 60 is similar to the last processed frame. Skipping...
# Frame 61 is similar to the last processed frame. Skipping...
# Frame 62 is similar to the last processed frame. Skipping...
# Frame 63 is similar to the last processed frame. Skipping...
# Frame 64 is similar to the last processed frame. Skipping...
# Frame 65 is similar to the last processed frame. Skipping...
# Frame 66 is similar to the last processed frame. Skipping...
# Frame 67 is similar to the last processed frame. Skipping...
# Frame 68 is similar to the last processed frame. Skipping...
# Frame 69 is similar to the last processed frame. Skipping...
# Frame 70 is similar to the last processed frame. Skipping...
# Frame 71 is similar to the last processed frame. Skipping...
# Frame 72 is similar to the last processed frame. Skipping...
# Frame 73 is similar to the last processed frame. Skipping...
# Frame 74 is similar to the last processed frame. Skipping...
# Frame 75 is similar to the last processed frame. Skipping...
# Frame 76 is similar to the last processed frame. Skipping...
# Frame 77 is similar to the last processed frame. Skipping...
# Frame 78 is similar to the last processed frame. Skipping...
# Frame 79 is similar to the last processed frame. Skipping...
# Frame 80 is similar to the last processed frame. Skipping...
# Frame 81 is similar to the last processed frame. Skipping...
# Frame 82 is similar to the last processed frame. Skipping...
# Frame 83 is similar to the last processed frame. Skipping...
# Frame 84 is similar to the last processed frame. Skipping...
# Frame 85 is similar to the last processed frame. Skipping...
# Frame 86 is similar to the last processed frame. Skipping...
# Frame 87 is similar to the last processed frame. Skipping...
# Frame 88 is similar to the last processed frame. Skipping...
# Frame 89 is similar to the last processed frame. Skipping...
# Frame 90 is similar to the last processed frame. Skipping...
# Frame 91 is similar to the last processed frame. Skipping...
# Frame 92 is similar to the last processed frame. Skipping...
# Frame 93 is similar to the last processed frame. Skipping...
# Frame 94 is similar to the last processed frame. Skipping...
# Frame 95 is similar to the last processed frame. Skipping...
# Frame 96 is similar to the last processed frame. Skipping...
# Frame 97 is similar to the last processed frame. Skipping...
# Frame 98 is similar to the last processed frame. Skipping...
# Frame 99 is similar to the last processed frame. Skipping...
# Frame 100 is similar to the last processed frame. Skipping...
# Frame 101 is similar to the last processed frame. Skipping...
# Frame 102 is similar to the last processed frame. Skipping...
# Frame 103 is similar to the last processed frame. Skipping...
# Frame 104 is similar to the last processed frame. Skipping...
# Frame 105 is similar to the last processed frame. Skipping...
# Frame 106 is similar to the last processed frame. Skipping...
# Frame 107 is similar to the last processed frame. Skipping...
# Frame 108 is similar to the last processed frame. Skipping...
# Frame 109 is similar to the last processed frame. Skipping...
# Frame 110 is similar to the last processed frame. Skipping...
# Frame 111 is similar to the last processed frame. Skipping...
# Frame 112 is similar to the last processed frame. Skipping...
# Frame 113 is similar to the last processed frame. Skipping...
# Frame 114 is similar to the last processed frame. Skipping...
# Frame 115 is similar to the last processed frame. Skipping...
# Frame 116 is similar to the last processed frame. Skipping...
# Frame 117 is similar to the last processed frame. Skipping...
# Frame 118 is similar to the last processed frame. Skipping...
# Frame 119 is similar to the last processed frame. Skipping...
# Frame 120 is similar to the last processed frame. Skipping...
# Frame 121 is similar to the last processed frame. Skipping...
# Frame 122 is similar to the last processed frame. Skipping...
# Frame 123 is similar to the last processed frame. Skipping...
# Frame 124 is similar to the last processed frame. Skipping...
# Frame 125 is similar to the last processed frame. Skipping...
# Frame 126 is similar to the last processed frame. Skipping...
# Frame 127 is similar to the last processed frame. Skipping...
# Frame 128 is similar to the last processed frame. Skipping...
# Frame 129 is similar to the last processed frame. Skipping...
# Frame 130 is similar to the last processed frame. Skipping...
# Frame 131 is similar to the last processed frame. Skipping...
# Frame 132 is similar to the last processed frame. Skipping...
# Frame 133 is similar to the last processed frame. Skipping...
# Frame 134 is similar to the last processed frame. Skipping...
# Frame 135 is similar to the last processed frame. Skipping...
# Frame 136 is similar to the last processed frame. Skipping...
# Frame 137 is similar to the last processed frame. Skipping...
# Frame 138 is similar to the last processed frame. Skipping...
# Frame 139 is similar to the last processed frame. Skipping...
# Frame 140 is similar to the last processed frame. Skipping...
# Frame 141 is similar to the last processed frame. Skipping...
# Frame 142 is similar to the last processed frame. Skipping...
# Frame 143 is similar to the last processed frame. Skipping...
# Frame 144 is similar to the last processed frame. Skipping...
# Frame 145 is similar to the last processed frame. Skipping...
# Frame 146 is similar to the last processed frame. Skipping...
# Frame 147 is similar to the last processed frame. Skipping...
# Frame 148 is similar to the last processed frame. Skipping...
# Frame 149 is similar to the last processed frame. Skipping...
# Frame 150 is similar to the last processed frame. Skipping...
# Overall Average Processing Time: 2.99 seconds
# Overall FPS: 37.95
